# %% [markdown]
# ## Sentimental Analysis On News Data

# %% [markdown]
# ## Data Understanding

# %% [markdown]
# The data is from global news dataset which has three datasets i.e data.csv, dormains_location and traffic files that contains infomation from articles collected over the past few months.The dataset has been sourced from kaggle
# data.csv has the following columns
# - article_id: Unique article id
# - source_id
# - source_name: Source name
# - author: The author of the article
# - title: The headline or title of the article.
# - description: A description or snippet from the article.
# - url: The direct URL to the article.
# - url_to_image: The URL to a relevant image for the article.
# - published_at: The date and time that the article was published, in UTC
# - content: The unformatted content of the article, where available. This is truncated to 200 chars
# - category: Search query used to fetch data
# - article: Full content of that article
# - title_sentiment: Sentiment of the title
#
# dormain_location has this columns
#
# - SourceCommonName: Common  Domain Name (bbc.co.uk, cnn.com)
# -
# location: Country short code (US, UK, CA)-
# Country: Country nam
# traffic.csv contains
# - GlobalRank: Rank of the domain globally
# -
# TldRank: Rank of the TLD:-
# TLD: TLD (Top-Level Doma c- ])
# RefSubNets: The number of Referring Subnets found for this domain in the Fresh Ind- ex.
# RefIPs: The number of Referring IPs found for this domain in the Fresh In- dex.
# IDN_Domain: Internationalized Domain-  Name
# IDN_TLD: Internationalized Domain Name Top-Level D- omain.
# PrevGlobalRank: Previous Globa- l Rank.
# PrevTldRank: Previous T- LD Rank.
# PrevRefSubNets: Previous number of referrin
#   g-  subnets.
# PrevRefIPs: Previous number of referring IPse

# %% [markdown]
# #### Importing libraries

# %%
#checking the envrionment
import sys
sys.executable
# Out:
# 'C:\\Users\\User\\anaconda3\\envs\\learn-env\\python.exe'

# %%
# importing relevant libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# loading data in data.csv
data = pd.read_csv("data.csv")
data.head()
# Out:
#    article_id source_id                   source_name
# 0       89541       NaN  International Business Times  \
# 1       89542       NaN                    Prtimes.jp
# 2       89543       NaN                      VOA News
# 3       89545       NaN            The Indian Express
# 4       89547       NaN           The Times of Israel
#
#                                        author
# 0                              Paavan MATHEMA  \
# 1                                         NaN
# 2  webdesk@voanews.com (Agence France-Presse)
# 3                                   Editorial
# 4                                 Jacob Magid
#
#                                                title
# 0  UN Chief Urges World To 'Stop The Madness' Of ...  \
# 1              RANDEBOOよりワンランク上の大人っぽさが漂うニットとベストが新登場。
# 2  UN Chief Urges World to 'Stop the Madness' of ...
# 3  Sikkim warning: Hydroelectricity push must be ...
# 4  200 foreigners, dual nationals cut down in Ham...
#
# ...

# %%
# load and preview data in traffic datset
traffic = pd.read_csv('traffic.csv')bn
traffic.head()
# Out:
#    GlobalRank  TldRank         Domain  TLD  RefSubNets   RefIPs
# 0           1        1     google.com  com      471274  2151358  \
# 1           2        2   facebook.com  com      465424  2250631
# 2           3        3    youtube.com  com      420579  1852995
# 3           4        4    twitter.com  com      404985  1757127
# 4           5        5  instagram.com  com      364746  1598085
#
#       IDN_Domain IDN_TLD  PrevGlobalRank  PrevTldRank  PrevRefSubNets
# 0     google.com     com               1            1          471248  \
# 1   facebook.com     com               2            2          465297
# 2    youtube.com     com               3            3          420483
# 3    twitter.com     com               4            4          404998
# 4  instagram.com     com               5            5          364618
#
#    PrevRefIPs
# 0     2147402
# 1     2247135
# 2     1848940
# 3     1753939
# 4     1594892

# %%
# load and preview data in traffic datset
location = pd.read_csv('domains_location.csv')
location.head()
# Out:
#   SourceCommonName location    Country
# 0       00221.info       SG    Senegal
# 1        01net.com       FR     France
# 2         01net.it       IT      Italy
# 3      0223.com.ar       AR  Argentina
# 4     022china.com       CH      China

# %%
# checking the shape
print(data.shape)
print(traffic.shape)
print(location.shape)
# Out:
# (105375, 12)
# (1000000, 12)
# (37802, 3)

# %%
# checking info
print(data.info)
# Out:
# <bound method DataFrame.info of         article_id source_id                   source_name
# 0            89541       NaN  International Business Times  \
# 1            89542       NaN                    Prtimes.jp
# 2            89543       NaN                      VOA News
# 3            89545       NaN            The Indian Express
# 4            89547       NaN           The Times of Israel
# ...            ...       ...                           ...
# 105370      781108       NaN            The Indian Express
# 105371      781129       NaN                        Forbes
# 105372      781235       NaN                           NPR
# 105373      781240       NaN                        Forbes
# 105374      781308       NaN                        Forbes
#
#                                                    author
# 0                                          Paavan MATHEMA  \
# 1                                                     NaN
# ...

# %%
# checking info
print(traffic.info)
print(location.info)
# Out:
# <bound method DataFrame.info of         GlobalRank  TldRank                  Domain  TLD  RefSubNets   RefIPs
# 0                1        1              google.com  com      471274  2151358  \
# 1                2        2            facebook.com  com      465424  2250631
# 2                3        3             youtube.com  com      420579  1852995
# 3                4        4             twitter.com  com      404985  1757127
# 4                5        5           instagram.com  com      364746  1598085
# ...            ...      ...                     ...  ...         ...      ...
# 999995      999996   485324              kireie.com  com         222      280
# 999996      999997   485325             mt-lock.com  com         222      280
# 999997      999998   485326           pinkwater.com  com         222      280
# 999998      999999   485327          soderhomes.com  com         222      280
# 999999     1000000   485328  toyotamusicfactory.com  com         222      280
#
# ...
